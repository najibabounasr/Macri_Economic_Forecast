# %% [markdown]
# # Beggining Training
# ### We will begin training our model by importing the necessary libraries and loading the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# we will be creating a VAR model, install the statsmodels library
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from statsmodels.tsa.stattools import grangercausalitytests
from funcs.machine_learning import check_stationarity, plot_series_stationarity

data = pd.read_csv('economic_data.csv', index_col='Date', parse_dates=True)

# %%
# temporarily drop all columns with ANY missing values
# Drop all columns with any missing values
data = data.dropna(axis=1)

# %%
for column in data.columns:
    print(f'Checking stationarity of {column}')
    check_stationarity(data[column])
    plot_series_stationarity(data[column])
# Out:
# Checking stationarity of FEDFUNDS
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -2.897496
# p-value                          0.045640
# #Lags Used                      17.000000
# Number of Observations Used    763.000000
# Critical Value (1%)             -3.438950
# Critical Value (5%)             -2.865335
# Critical Value (10%)            -2.568791
# dtype: float64
# Checking stationarity of GDP
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -2.197451
# p-value                          0.207172
# #Lags Used                      16.000000
# Number of Observations Used    764.000000
# Critical Value (1%)             -3.438938
# Critical Value (5%)             -2.865330
# Critical Value (10%)            -2.568788
# dtype: float64
# Checking stationarity of CPIAUCSL
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                   1.964497
# p-value                          0.998625
# #Lags Used                      15.000000
# Number of Observations Used    765.000000
# Critical Value (1%)             -3.438927
# Critical Value (5%)             -2.865325
# Critical Value (10%)            -2.568786
# dtype: float64
# Checking stationarity of CUSR0000SAH1
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                   2.349400
# p-value                          0.998984
# #Lags Used                      12.000000
# Number of Observations Used    768.000000
# Critical Value (1%)             -3.438893
# Critical Value (5%)             -2.865311
# Critical Value (10%)            -2.568778
# dtype: float64
# Checking stationarity of CPILFESL
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                   1.994710
# p-value                          0.998666
# #Lags Used                      13.000000
# Number of Observations Used    767.000000
# Critical Value (1%)             -3.438905
# Critical Value (5%)             -2.865316
# Critical Value (10%)            -2.568781
# dtype: float64
# Checking stationarity of PCE
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -2.398390
# p-value                          0.142191
# #Lags Used                       3.000000
# Number of Observations Used    777.000000
# Critical Value (1%)             -3.438794
# Critical Value (5%)             -2.865267
# Critical Value (10%)            -2.568755
# dtype: float64
# Checking stationarity of PRFI
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.614404
# p-value                          0.475664
# #Lags Used                      20.000000
# Number of Observations Used    760.000000
# Critical Value (1%)             -3.438984
# Critical Value (5%)             -2.865350
# Critical Value (10%)            -2.568799
# dtype: float64
# Checking stationarity of PNFI
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.744471
# p-value                          0.408358
# #Lags Used                      13.000000
# Number of Observations Used    767.000000
# Critical Value (1%)             -3.438905
# Critical Value (5%)             -2.865316
# Critical Value (10%)            -2.568781
# dtype: float64
# Checking stationarity of EXPGS
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.847914
# p-value                          0.356946
# #Lags Used                      20.000000
# Number of Observations Used    760.000000
# Critical Value (1%)             -3.438984
# Critical Value (5%)             -2.865350
# Critical Value (10%)            -2.568799
# dtype: float64
# Checking stationarity of HOUST
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -3.261505
# p-value                          0.016689
# #Lags Used                      15.000000
# Number of Observations Used    765.000000
# Critical Value (1%)             -3.438927
# Critical Value (5%)             -2.865325
# Critical Value (10%)            -2.568786
# dtype: float64
# Checking stationarity of DSPI
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -2.457225
# p-value                          0.126232
# #Lags Used                      14.000000
# Number of Observations Used    766.000000
# Critical Value (1%)             -3.438916
# Critical Value (5%)             -2.865321
# Critical Value (10%)            -2.568783
# dtype: float64
# Checking stationarity of AAA
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.530720
# p-value                          0.518264
# #Lags Used                       8.000000
# Number of Observations Used    772.000000
# Critical Value (1%)             -3.438849
# Critical Value (5%)             -2.865291
# Critical Value (10%)            -2.568767
# dtype: float64
# Checking stationarity of BAA
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.642768
# p-value                          0.460815
# #Lags Used                       5.000000
# Number of Observations Used    775.000000
# Critical Value (1%)             -3.438816
# Critical Value (5%)             -2.865277
# Critical Value (10%)            -2.568760
# dtype: float64
# Checking stationarity of WTISPLC
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.712588
# p-value                          0.424639
# #Lags Used                       6.000000
# Number of Observations Used    774.000000
# Critical Value (1%)             -3.438827
# Critical Value (5%)             -2.865281
# Critical Value (10%)            -2.568762
# dtype: float64
# Checking stationarity of IMPGS
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -2.132985
# p-value                          0.231460
# #Lags Used                      12.000000
# Number of Observations Used    768.000000
# Critical Value (1%)             -3.438893
# Critical Value (5%)             -2.865311
# Critical Value (10%)            -2.568778
# dtype: float64
# Checking stationarity of GCE
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.881292
# p-value                          0.340913
# #Lags Used                      18.000000
# Number of Observations Used    762.000000
# Critical Value (1%)             -3.438961
# Critical Value (5%)             -2.865340
# Critical Value (10%)            -2.568794
# dtype: float64
# Checking stationarity of FGCE
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.419134
# p-value                          0.573069
# #Lags Used                      19.000000
# Number of Observations Used    761.000000
# Critical Value (1%)             -3.438972
# Critical Value (5%)             -2.865345
# Critical Value (10%)            -2.568796
# dtype: float64
# Checking stationarity of GDPCTPI
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                   1.922733
# p-value                          0.998564
# #Lags Used                      21.000000
# Number of Observations Used    759.000000
# Critical Value (1%)             -3.438995
# Critical Value (5%)             -2.865355
# Critical Value (10%)            -2.568802
# dtype: float64
# Checking stationarity of PCEPI
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                   1.375470
# p-value                          0.997000
# #Lags Used                      15.000000
# Number of Observations Used    765.000000
# Critical Value (1%)             -3.438927
# Critical Value (5%)             -2.865325
# Critical Value (10%)            -2.568786
# dtype: float64
# Checking stationarity of PCEPILFE
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                   1.183544
# p-value                          0.995870
# #Lags Used                      17.000000
# Number of Observations Used    763.000000
# Critical Value (1%)             -3.438950
# Critical Value (5%)             -2.865335
# Critical Value (10%)            -2.568791
# dtype: float64
# Checking stationarity of PAYEMS
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -0.566826
# p-value                          0.878303
# #Lags Used                       2.000000
# Number of Observations Used    778.000000
# Critical Value (1%)             -3.438783
# Critical Value (5%)             -2.865262
# Critical Value (10%)            -2.568752
# dtype: float64
# Checking stationarity of UNRATE
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -3.374293
# p-value                          0.011867
# #Lags Used                       2.000000
# Number of Observations Used    778.000000
# Critical Value (1%)             -3.438783
# Critical Value (5%)             -2.865262
# Critical Value (10%)            -2.568752
# dtype: float64
# Checking stationarity of INDPRO
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -1.082258
# p-value                          0.722095
# #Lags Used                      11.000000
# Number of Observations Used    769.000000
# Critical Value (1%)             -3.438882
# Critical Value (5%)             -2.865306
# Critical Value (10%)            -2.568775
# dtype: float64
# Checking stationarity of CUMFNS
# Results of Augmented Dickey-Fuller Test:
# Test Statistic                  -3.771246
# p-value                          0.003216
# #Lags Used                      11.000000
# Number of Observations Used    769.000000
# Critical Value (1%)             -3.438882
# Critical Value (5%)             -2.865306
# Critical Value (10%)            -2.568775
# dtype: float64

# %% [markdown]
# # Initial Test Results:
#
# To analyze the stationarity of the data, we can look at the p-values from the Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the data has a unit root, implying it is non-stationary. Therefore, if the p-value is less than a chosen significance level (commonly 0.05), we reject the null hypothesis and consider the data stationary.
#
# ### Stationary:
# FEDFUNDS: p-value = 0.045640 < 0.05
#
# HOUST: p-value = 0.016689 < 0.05
#
# UNRATE: p-value = 0.011867 < 0.05
#
# CUMFNS: p-value = 0.003216 < 0.05
#
# ### Non-Stationary:
# GDP: p-value = 0.207172 > 0.05
#
# CPIAUCSL: p-value = 0.998625 > 0.05
#
# CUSR0000SAH1: p-value = 0.998984 > 0.05
#
# CPILFESL: p-value = 0.998666 > 0.05
#
# PCE: p-value = 0.142191 > 0.05
#
# PRFI: p-value = 0.475664 > 0.05
#
# PNFI: p-value = 0.408358 > 0.05
#
# EXPGS: p-value = 0.356946 > 0.05
#
# DSPI: p-value = 0.126232 > 0.05
#
# AAA: p-value = 0.518264 > 0.05
#
# BAA: p-value = 0.460815 > 0.05
#
# WTISPLC: p-value = 0.424639 > 0.05
#
# IMPGS: p-value = 0.231460 > 0.05
#
# GCE: p-value = 0.340913 > 0.05
#
# FGCE: p-value = 0.573069 > 0.05
#
# GDPCTPI: p-value = 0.998564 > 0.05
#
# PCEPI: p-value = 0.997000 > 0.05
#
# PCEPILFE: p-value = 0.995870 > 0.05
#
# PAYEMS: p-value = 0.878303 > 0.05
#
# INDPRO: p-value = 0.722095 > 0.05

# %% [markdown]
# # Stationarity Analysis
# ### Stationary Variables:
# Variables are typically considered stationary if the p-value is less than 0.05, which suggests that we can reject the null hypothesis that there is a unit root present in the time series. From your results, the variables considered stationary are:
#
# HOUST: Housing starts, p-value = 0.016689.
#
# UNRATE: Unemployment rate, p-value = 0.011867.
#
# CUMFNS: Cumulative function, p-value = 0.003216.
#
# ## Non-Stationary Variables:
# Variables with a p-value greater than 0.05 are generally considered non-stationary. This includes most of your variables, such as GDP, CPIAUCSL, FEDFUNDS, and others. The non-stationary variables need some form of differencing or transformation to achieve stationarity.
#
# ## Insights and Recommendations
# #### High p-values for Price Indices: Variables like CPIAUCSL, PCEPI, and CUSR0000SAH1 have very high p-values close to 1. This indicates a very strong presence of a unit root, suggesting these series are highly non-stationary. Such series are typically persistent over time, reflecting cumulative inflation effects.
#
# #### FEDFUNDS Close to Stationarity: The Federal Funds Rate (FEDFUNDS) has a p-value of 0.045640, which is marginally below the 0.05 threshold. This might suggest some level of stationarity, although it's close to the cutoff. This could be due to policy interventions that stabilize interest rates over certain periods.
#
# #### Employment and Industrial Production: Variables related to economic activity like PAYEMS and INDPRO are not stationary, which might indicate cyclical patterns associated with business cycles.

# %%
# Check initial NaN counts
print(data.isnull().sum())

# Optionally, fill NaNs or drop them
# data.fillna(method='ffill', inplace=True)  # Forward fill
# data.dropna(inplace=True)  # Drop rows with NaNs
# Out:
# FEDFUNDS        0
# GDP             0
# CPIAUCSL        0
# CUSR0000SAH1    0
# CPILFESL        0
# PCE             0
# PRFI            0
# PNFI            0
# EXPGS           0
# HOUST           0
# DSPI            0
# AAA             0
# BAA             0
# WTISPLC         0
# IMPGS           0
# GCE             0
# FGCE            0
# GDPCTPI         0
# PCEPI           0
# PCEPILFE        0
# PAYEMS          0
# UNRATE          0
# INDPRO          0
# CUMFNS          0
# dtype: int64

# %%
# Check for zeros
print((data == 0).sum())

# Apply pct_change and immediately handle infinities
data = data.pct_change().replace([np.inf, -np.inf], np.nan).dropna()
# Out:
# FEDFUNDS        0
# GDP             0
# CPIAUCSL        0
# CUSR0000SAH1    0
# CPILFESL        0
# PCE             0
# PRFI            0
# PNFI            0
# EXPGS           0
# HOUST           0
# DSPI            0
# AAA             0
# BAA             0
# WTISPLC         0
# IMPGS           0
# GCE             0
# FGCE            0
# GDPCTPI         0
# PCEPI           0
# PCEPILFE        0
# PAYEMS          0
# UNRATE          0
# INDPRO          0
# CUMFNS          0
# dtype: int64

# %%
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

def check_stationarity(series):
    result = adfuller(series, autolag='AIC')
    print(f'ADF Statistic: {result[0]}')
    print(f'p-value: {result[1]}')
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'\t{key}: {value}')

def plot_series_stationarity(series):
    plt.figure(figsize=(10, 4))
    plt.plot(series)
    plt.title('Time Series (Stationarity Check)')
    plt.show()

# Display null counts after transformation
print(data.isnull().sum())

# Check and plot stationarity for each column
for column in data.columns:
    print(f'Checking stationarity of {column}')
    check_stationarity(data[column])
    plot_series_stationarity(data[column])
# Out:
# FEDFUNDS        0
# GDP             0
# CPIAUCSL        0
# CUSR0000SAH1    0
# CPILFESL        0
# PCE             0
# PRFI            0
# PNFI            0
# EXPGS           0
# HOUST           0
# DSPI            0
# AAA             0
# BAA             0
# WTISPLC         0
# IMPGS           0
# GCE             0
# FGCE            0
# GDPCTPI         0
# PCEPI           0
# PCEPILFE        0
# PAYEMS          0
# UNRATE          0
# INDPRO          0
# CUMFNS          0
# dtype: int64
# Checking stationarity of FEDFUNDS
# ADF Statistic: -7.7737035932611045
# p-value: 8.782754714679567e-12
# Critical Values:
# 	1%: -3.4388489336836003
# 	5%: -2.865291103159288
# 	10%: -2.568767459327767
# Checking stationarity of GDP
# ADF Statistic: -6.049867099747038
# p-value: 1.2852589708927205e-07
# Critical Values:
# 	1%: -3.438938229437747
# 	5%: -2.8653304587462944
# 	10%: -2.568788425002056
# Checking stationarity of CPIAUCSL
# ADF Statistic: -3.0661162203202768
# p-value: 0.029164495516821952
# Critical Values:
# 	1%: -3.438926964986094
# 	5%: -2.8653254941943174
# 	10%: -2.5687857802554572
# Checking stationarity of CUSR0000SAH1
# ADF Statistic: -3.443059955476027
# p-value: 0.009575670400385665
# Critical Values:
# 	1%: -3.439006442437876
# 	5%: -2.865360521688131
# 	10%: -2.5688044403756587
# Checking stationarity of CPILFESL
# ADF Statistic: -2.995034618360831
# p-value: 0.0353607135657739
# Critical Values:
# 	1%: -3.4388933482333464
# 	5%: -2.8653106782623574
# 	10%: -2.5687778874376086
# Checking stationarity of PCE
# ADF Statistic: -7.276266757612159
# p-value: 1.541568832039751e-10
# Critical Values:
# 	1%: -3.4388710830827125
# 	5%: -2.8653008652386576
# 	10%: -2.568772659807725
# Checking stationarity of PRFI
# ADF Statistic: -5.991838788523865
# p-value: 1.7381980570095366e-07
# Critical Values:
# 	1%: -3.4389835846902788
# 	5%: -2.8653504478604757
# 	10%: -2.5687990737534627
# Checking stationarity of PNFI
# ADF Statistic: -6.02773613839563
# p-value: 1.4423929168654527e-07
# Critical Values:
# 	1%: -3.438915730045254
# 	5%: -2.8653205426302253
# 	10%: -2.5687831424305845
# Checking stationarity of EXPGS
# ADF Statistic: -6.061321071844265
# p-value: 1.2106578935538073e-07
# Critical Values:
# 	1%: -3.4389835846902788
# 	5%: -2.8653504478604757
# 	10%: -2.5687990737534627
# Checking stationarity of HOUST
# ADF Statistic: -8.44644267360666
# p-value: 1.7077506992302638e-13
# Critical Values:
# 	1%: -3.4388933482333464
# 	5%: -2.8653106782623574
# 	10%: -2.5687778874376086
# Checking stationarity of DSPI
# ADF Statistic: -6.666997402095553
# p-value: 4.690319891877907e-09
# Critical Values:
# 	1%: -3.4389045244994096
# 	5%: -2.8653156040031176
# 	10%: -2.5687805115003
# Checking stationarity of AAA
# ADF Statistic: -7.3564372035936065
# p-value: 9.752573107435393e-11
# Critical Values:
# 	1%: -3.4389045244994096
# 	5%: -2.8653156040031176
# 	10%: -2.5687805115003
# Checking stationarity of BAA
# ADF Statistic: -7.128656449570544
# p-value: 3.565020932490025e-10
# Critical Values:
# 	1%: -3.4389045244994096
# 	5%: -2.8653156040031176
# 	10%: -2.5687805115003
# Checking stationarity of WTISPLC
# ADF Statistic: -14.935650508783057
# p-value: 1.3458543089187034e-27
# Critical Values:
# 	1%: -3.438804978547988
# 	5%: -2.8652717302548396
# 	10%: -2.5687571389759802
# Checking stationarity of IMPGS
# ADF Statistic: -7.927217673550718
# p-value: 3.591852210069196e-12
# Critical Values:
# 	1%: -3.4388933482333464
# 	5%: -2.8653106782623574
# 	10%: -2.5687778874376086
# Checking stationarity of GCE
# ADF Statistic: -3.962534170732172
# p-value: 0.0016199122315927344
# Critical Values:
# 	1%: -3.4389608473398194
# 	5%: -2.8653404270188476
# 	10%: -2.568793735369693
# Checking stationarity of FGCE
# ADF Statistic: -4.383187315496443
# p-value: 0.00031784292463351394
# Critical Values:
# 	1%: -3.4389722010249386
# 	5%: -2.8653454308425705
# 	10%: -2.5687964010457227
# Checking stationarity of GDPCTPI
# ADF Statistic: -2.5889547398152657
# p-value: 0.095301653914515
# Critical Values:
# 	1%: -3.4389949984547465
# 	5%: -2.865355478124818
# 	10%: -2.568801753520772
# Checking stationarity of PCEPI
# ADF Statistic: -2.9059832117958497
# p-value: 0.04465664220336896
# Critical Values:
# 	1%: -3.438926964986094
# 	5%: -2.8653254941943174
# 	10%: -2.5687857802554572
# Checking stationarity of PCEPILFE
# ADF Statistic: -2.8226399195597547
# p-value: 0.05511188144636903
# Critical Values:
# 	1%: -3.4388268991356936
# 	5%: -2.8652813916285518
# 	10%: -2.5687622857867782
# Checking stationarity of PAYEMS
# ADF Statistic: -20.74998219347923
# p-value: 0.0
# Critical Values:
# 	1%: -3.438783171038672
# 	5%: -2.865262118650577
# 	10%: -2.568752018688748
# Checking stationarity of UNRATE
# ADF Statistic: -26.015951051282965
# p-value: 0.0
# Critical Values:
# 	1%: -3.4387723094153286
# 	5%: -2.8652573313919625
# 	10%: -2.5687494684274794
# Checking stationarity of INDPRO
# ADF Statistic: -7.225712147287153
# p-value: 2.0557247121318123e-10
# Critical Values:
# 	1%: -3.438882201132452
# 	5%: -2.865305765357574
# 	10%: -2.568775270215655
# Checking stationarity of CUMFNS
# ADF Statistic: -21.28224826771382
# p-value: 0.0
# Critical Values:
# 	1%: -3.4387723094153286
# 	5%: -2.8652573313919625
# 	10%: -2.5687494684274794

# %% [markdown]
# ## Variables that Became Stationary
# These variables have shown significant improvement in terms of stationarity as their p-values are now below 0.05, suggesting rejection of the null hypothesis of a unit root (indicating stationarity):
#
# FEDFUNDS: Improved significantly, showing signs of stationarity.
#
# GDP: Major improvement, indicating stationarity.
#
# CPIAUCSL: Now shows stationarity which is a notable change.
#
# CUSR0000SAH1, CPILFESL, PCE, PRFI, PNFI, EXPGS: All these variables have shown improvements and are now stationary.
#
# HOUST: Remains stationary, with an even more significant p-value.
#
# PCEPI: Shows substantial improvement and is now stationary.
#
# ## Variables Still Non-Stationary
# These variables still show p-values above 0.05, indicating that they are not stationary and may require further differencing or transformations:
#
# DSPI, AAA, BAA, WTISPLC: While some improvement is noted, these remain non-stationary.
#
# IMPGS, GCE, FGCE, GDPCTPI: These continue to show non-stationarity and might need additional transformations or differencing.
#
# PCEPILFE: Shows improvement but still hovers around the threshold of stationarity.

# %%
# import the Var module
from statsmodels.tsa.api import VAR 
# 1 Arima
# 2 SARIMA
# 3 FB Prophet
# 4 Regressor model
# 5 Random Forest model
# 6 lightgbm
# 7 XGboost
# 8 Auto gluon 

# ML-Flow  

# Cut the dataframe so that it starts at 1976-02-01
data = data['1976-02-01':]

# save this data as a new 'streamlit_ready_data.csv' file
data.to_csv('streamlit_ready_data.csv')
